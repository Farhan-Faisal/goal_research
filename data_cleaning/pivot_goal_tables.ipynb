# %%
import pandas as pd
import os

# %%
goal_path = "../data/labelled_goals/daily_goal_embeddings.csv"

# %%
cols = ["ParticipantIdentifier", "ResultIdentifier", "Answers", "trial_date", "label", "embedding"]
goal_df = pd.read_csv(goal_path)[cols].drop_duplicates(subset=['ParticipantIdentifier', 'ResultIdentifier', 'trial_date'])
goal_df.head()
# Out:
#                   ParticipantIdentifier ResultIdentifier  \
# 0  1b9b62f1-095b-4819-92a0-ea8e7abee884  DAILY_goal2_set
# 1  6e86c427-c679-4acd-aeb4-19ada9022b66  DAILY_goal2_set
# 2  7d501571-5d23-4f09-9266-1644f4f71add  DAILY_goal1_set
# 3  7d501571-5d23-4f09-9266-1644f4f71add  DAILY_goal2_set
# 4  8a5a92f3-472a-4a39-bfd8-f43f60fdcd27  DAILY_goal1_set
#
#                         Answers  trial_date            label  \
# 0                          Read  2022-10-24  Reading_leisure
# 1               review more c37  2022-10-24           School
# 2  Study for psychology midterm  2022-10-24           School
# 3               Get active more  2022-10-24         Exercise
# 4                      Psy note  2022-10-24           School
#
#                                            embedding
# 0  [0.014083514921367168, 0.021316660568118095, -...
# 1  [-0.010716583579778671, 0.03636825829744339, -...
# 2  [0.0011260673636570573, -0.021096592769026756,...
# 3  [-0.026380401104688644, 0.03562040999531746, -...
# 4  [0.01974469982087612, -0.0020304976496845484, ...

# %%
goal_wide = goal_df[["ParticipantIdentifier", "ResultIdentifier", "Answers", "trial_date"]].pivot(
    index=['ParticipantIdentifier', 'trial_date'],
    columns=['ResultIdentifier'], 
    values='Answers'
).reset_index()

label_wide = goal_df[["ParticipantIdentifier", "ResultIdentifier", "trial_date", "label"]].pivot(
    index=['ParticipantIdentifier', 'trial_date'],
    columns=['ResultIdentifier'], 
    values='label'
).rename(columns={
    "DAILY_goal1_set": "DAILY_goal1_label",
    "DAILY_goal2_set": "DAILY_goal2_label"
}).reset_index()

embedding_wide = goal_df[["ParticipantIdentifier", "ResultIdentifier", "trial_date","embedding"]].pivot(
    index=['ParticipantIdentifier', 'trial_date'],
    columns=['ResultIdentifier'], 
    values='embedding'
).rename(columns={
    "DAILY_goal1_set": "DAILY_goal1_embedding",
    "DAILY_goal2_set": "DAILY_goal2_embedding"
}).reset_index()

# %%
goal_wide.head(3)
# Out:
# ResultIdentifier                 ParticipantIdentifier  trial_date  \
# 0                 0501ba67-3406-4779-aff1-878a0e9f7885  2022-09-30
# 1                 0501ba67-3406-4779-aff1-878a0e9f7885  2022-10-03
# 2                 0501ba67-3406-4779-aff1-878a0e9f7885  2022-10-07
#
# ResultIdentifier                                    DAILY_goal1_set  \
# 0                 Study history and psychology, practice the violin
# 1                                                            review
# 2                                               practice the violin
#
# ResultIdentifier DAILY_goal2_set
# 0                    Do exercise
# 1                   movie review
# 2                       Work out

# %%
label_wide.head(3)
# Out:
# ResultIdentifier                 ParticipantIdentifier  trial_date  \
# 0                 0501ba67-3406-4779-aff1-878a0e9f7885  2022-09-30
# 1                 0501ba67-3406-4779-aff1-878a0e9f7885  2022-10-03
# 2                 0501ba67-3406-4779-aff1-878a0e9f7885  2022-10-07
#
# ResultIdentifier DAILY_goal1_label DAILY_goal2_label
# 0                           School          Exercise
# 1                           School           Culture
# 2                            Hobby          Exercise

# %%
embedding_wide.head(3)
# Out:
# ResultIdentifier                 ParticipantIdentifier  trial_date  \
# 0                 0501ba67-3406-4779-aff1-878a0e9f7885  2022-09-30
# 1                 0501ba67-3406-4779-aff1-878a0e9f7885  2022-10-03
# 2                 0501ba67-3406-4779-aff1-878a0e9f7885  2022-10-07
#
# ResultIdentifier                              DAILY_goal1_embedding  \
# 0                 [-0.038126230239868164, -0.021308906376361847,...
# 1                 [0.03161436691880226, 0.029465556144714355, -0...
# 2                 [-0.01599280908703804, -0.0059240879490971565,...
#
# ResultIdentifier                              DAILY_goal2_embedding
# 0                 [-0.012392040342092514, 0.017055129632353783, ...
# 1                 [-0.02972441539168358, 0.03863658756017685, -0...
# 2                 [-0.03653150796890259, 0.02275843359529972, -0...

# %%
goal_wide = goal_wide.merge(label_wide, on=["ParticipantIdentifier", "trial_date"])
goal_wide = goal_wide.merge(embedding_wide, on=["ParticipantIdentifier", "trial_date"])

# %%
goal_wide.head(3)
# Out:
# ResultIdentifier                 ParticipantIdentifier  trial_date  \
# 0                 0501ba67-3406-4779-aff1-878a0e9f7885  2022-09-30
# 1                 0501ba67-3406-4779-aff1-878a0e9f7885  2022-10-03
# 2                 0501ba67-3406-4779-aff1-878a0e9f7885  2022-10-07
#
# ResultIdentifier                                    DAILY_goal1_set  \
# 0                 Study history and psychology, practice the violin
# 1                                                            review
# 2                                               practice the violin
#
# ResultIdentifier DAILY_goal2_set DAILY_goal1_label DAILY_goal2_label  \
# 0                    Do exercise            School          Exercise
# 1                   movie review            School           Culture
# 2                       Work out             Hobby          Exercise
#
# ResultIdentifier                              DAILY_goal1_embedding  \
# 0                 [-0.038126230239868164, -0.021308906376361847,...
# 1                 [0.03161436691880226, 0.029465556144714355, -0...
# 2                 [-0.01599280908703804, -0.0059240879490971565,...
#
# ResultIdentifier                              DAILY_goal2_embedding
# 0                 [-0.012392040342092514, 0.017055129632353783, ...
# 1                 [-0.02972441539168358, 0.03863658756017685, -0...
# 2                 [-0.03653150796890259, 0.02275843359529972, -0...

# %%
goal_wide.to_csv(os.path.join("../data/proc/goals/daily_goals_labeled_embedding_wide.csv"), index=False)
